# %%
name = "Даша"
group = "4731204/50003"
scoure = 100
print(f"Студентка {name} из группы {group} получила {scoure} баллов за тест")
# Out:
# Студентка Даша из группы 4731204/50003 получила 100 баллов за тест

# %%
f = open("C:\\Users\\Admin\\Downloads\\output.txt", "w", encoding="utf-8")
print("Высоцкая Дарья, учусь в СПбПУ на специальности 'Биотехнические системы и технологии' в группе 4731204/50003", file=f)
f.close()

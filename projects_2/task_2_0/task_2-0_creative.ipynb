# %%
print("*" * 48)
print("\t\tПРИВЕТСТВУЮ", end="!\n")
print("\n\tЯ студентка 1 курса 2026 года")
print("\nЖелаю Вам удачи", end="...")
print("и всего самого-самого лучшего")
print("*" * 48)
# Out:
# ************************************************
# 		ПРИВЕТСТВУЮ!
#
# 	Я студентка 1 курса 2026 года
#
# Желаю Вам удачи...и всего самого-самого лучшего
# ************************************************

# %%
course =  " Информатика"
current_floor_number = 2.2
number_of_completed_tasks = 9
print(f"курс: {course}, номер текущего этапа: {current_floor_number}, количество выполненных задач: {number_of_completed_tasks}.")
# Out:
# курс:  Информатика, номер текущего этапа: 2.2, количество выполненных задач: 9.

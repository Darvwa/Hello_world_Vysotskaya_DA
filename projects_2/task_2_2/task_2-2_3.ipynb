# %%
device_name = "микроскоп"
inventory_number = "м-001"
condition = "исправен" 
quantity = "8"
print(f"Название прибора\tИнвентарный номер\tСостояние\tКоличество\n\n{device_name}\t\t{inventory_number}\t\t\t{condition}\t{quantity}")
# Out:
# Название прибора	Инвентарный номер	Состояние	Количество
#
# микроскоп		м-001			исправен	8

# %%
name = input("Имя оператора: ")
pressure_sensor_value = input("Значение датчика давления (Па): ")
with open("C:\\Users\\Admin\\Downloads\\sensor_log.txt", "w", encoding="utf-8") as log:
    log.write(f"ОПЕРАТОР\tЗНАЧЕНИЕ\n\n{name}\t{pressure_sensor_value} (Па)")
print("Данные успешно сохранены в sensor_log.txt")
# Out:
# Имя оператора:  Высоцкая Д.А.
# Значение датчика давления (Па):  111.1
# Данные успешно сохранены в sensor_log.txt

# %%
proteins = float(input("Масса белков (г): "))
fats = float(input("Масса жиров (г): "))
carbs = float(input("Масса углеводов (г): "))
calories = (proteins * 4) + (fats * 9) + (carbs * 4)
print(f"Калорийность продукта: {calories} ккал")
# Out:
# Масса белков (г):  11.5
# Масса жиров (г):  20.1
# Масса углеводов (г):  32.4
# Калорийность продукта: 356.5 ккал

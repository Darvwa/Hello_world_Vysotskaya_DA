# %%
volume = float(input("Объем раствора (мл): "))
salt_mass = volume * 0.009
water_volume = volume
with open("C:\\Users\\Admin\\Downloads\\recipe.txt", "w", encoding="utf-8") as file:
    file.write(f"ОТЧЁТ ПО ПРИГОТОВЛЕНИЮ:\n{"-" * 23}\nОбщий объем: {volume} мл\nМасса соли: {salt_mass:.2f} г\nОбъем воды: {water_volume} мл\n")
print("Рецепт сохранен в файл recipe.txt")
# Out:
# Объем раствора (мл):  150
# Рецепт сохранен в файл recipe.txt

# %%
seq = [ "ATATACGCGTA", "CTTCGGNGGA" ]
for sequence in seq:
    print(f"Последовательность: {sequence}")
    print("Построчно:")
    for letter in sequence:
        print(letter)
print("\nЦикл выполнен")
# Out:
# Последовательность: ATATACGCGTA
# Построчно:
# A
# T
# A
# T
# A
# C
# G
# C
# G
# T
# A
# Последовательность: CTTCGGNGGA
# Построчно:
# C
# T
# T
# C
# G
# G
# N
# G
# G
# A
#
# Цикл выполнен

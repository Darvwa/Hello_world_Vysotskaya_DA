# %%
a = float(input("Ввести первое число: "))
b = float(input("Ввести второе число: "))
c = float(input("Ввести третье число: "))
d = float(input("Ввести четвертое число: "))

min = a

if b < min:
    min = b

if c < min:
    min = c

if d < min:
    min = d

print(f"Минимальное число: {min}")
# Out:
# Ввести первое число:  8
# Ввести второе число:  4
# Ввести третье число:  7
# Ввести четвертое число:  5
# Минимальное число: 4.0

# %%
N = int(input("Введите размер массива N: "))

if N <= 0:
    print("Ошибка: N должно быть > 0!")
else:
    A = []
    S = 0
    count = 0
    i = 1  
    
    while i <= N:
        element = float(input(f"Введите элемент A[{i}]: "))
        A.append(element)
        
        if i % 2 == 0:
            S = S + element
            count = count + 1
        
        i = i + 1

    if count > 0:
        Avg = S / count
    
        print(f"Среднее арифметическое: {Avg}")
    else:
        print("Нет элементов с четными индексами!")
# Out:
# Введите размер массива N:  5
# Введите элемент A[1]:  1
# Введите элемент A[2]:  2
# Введите элемент A[3]:  3
# Введите элемент A[4]:  4
# Введите элемент A[5]:  5
# Среднее арифметическое: 3.0

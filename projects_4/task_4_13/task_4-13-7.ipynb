# %%
N = int(input("Введите размер массива N: "))

if N <= 0:
    print("Ошибка: N должно быть > 0!")
else:
    A = []
    S = 0
    i = 1
    while i <= N:
        element = float(input(f"Введите элемент A[{i}]: "))
        A.append(element)
        S = S + element
        i = i + 1
    
Avg = S / N
    
print(f"Среднее арифметическое: {Avg}")
# Out:
# Введите размер массива N:  9
# Введите элемент A[1]:  3
# Введите элемент A[2]:  1
# Введите элемент A[3]:  6
# Введите элемент A[4]:  8
# Введите элемент A[5]:  3
# Введите элемент A[6]:  6
# Введите элемент A[7]:  9
# Введите элемент A[8]:  2
# Введите элемент A[9]:  5
# Среднее арифметическое: 4.777777777777778

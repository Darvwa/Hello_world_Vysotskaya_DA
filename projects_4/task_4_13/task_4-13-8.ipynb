# %%
N = int(input("Введите размер массива N: "))

if N <= 0:
    print("Ошибка: N должно быть > 0!")
else:
    A = []
    count = 0
    i = 1
    while i <= N:
        element = float(input(f"Введите элемент A[{i}]: "))
        A.append(element)

        if element > 0:
            count = count + 1
        
        i = i + 1
print(f"Количество положительных чисел в массиве: {count}")
# Out:
# Введите размер массива N:  4
# Введите элемент A[1]:  2
# Введите элемент A[2]:  7
# Введите элемент A[3]:  3
# Введите элемент A[4]:  9
# Количество положительных чисел в массиве: 4

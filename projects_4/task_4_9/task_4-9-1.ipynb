# %%
x = float(input("Введите число X: "))
y = float(input("Введите число Y: "))

if x > y:
    max_value = x
else:
    max_value = y

print("Максимальное число:", max_value)
# Out:
# Введите число X:  55
# Введите число Y:  9
# Максимальное число: 55.0
